# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.naive_bayes import GaussianNB
#pip install pandas
#pip install scikit-learn
#pip instll seaborn

# %%
da=pd.read_csv("DS_Jobs.csv")
da
# Out:
#              Job Title  Salary Estimate  \
# 0    Sr Data Scientist              171
# 1       Data Scientist              171
# 2       Data Scientist              171
# 3       Data Scientist              171
# 4       Data Scientist              171
# ..                 ...              ...
# 655     Data Scientist              167
# 656     Data Scientist              167
# 657     Data Scientist              167
# 658     Data Scientist              167
# 659     Data Scientist              167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# ...

# %%
da.head(2)
# Out:
#            Job Title  Salary Estimate  \
# 0  Sr Data Scientist              171
# 1     Data Scientist              171
#
#                                      Job Description  Rating Company Name  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1  Healthfirst
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2      ManTech
#
#         Location  Headquarters                     Size  \
# 0   New York, NY  New York, NY   1001 to 5000 employees
# 1  Chantilly, VA   Herndon, VA  5001 to 10000 employees
#
#         Type of ownership                Industry  ... company_age python  \
# 0  Nonprofit Organization      Insurance Carriers  ...          27      0
# 1        Company - Public  Research & Development  ...          52      0
#
#    excel  hadoop  spark aws  tableau  big_data        job_simp  seniority
# 0      0       0      0   1        0         0  data scientist     senior
# 1      0       1      0   0        0         1  data scientist         na
#
# ...

# %%
da.tail(5)
# Out:
#           Job Title  Salary Estimate  \
# 655  Data Scientist              167
# 656  Data Scientist              167
# 657  Data Scientist              167
# 658  Data Scientist              167
# 659  Data Scientist              167
#
#                                        Job Description  Rating  \
# 655  Summary\n\nWe’re looking for a data scientist ...     3.6
# 656  Job Description\nBecome a thought leader withi...     0.0
# 657  Join a thriving company that is changing the w...     0.0
# 658  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 659  Description\n\nThe Data Scientist will be part...     2.7
#
#              Company Name           Location     Headquarters  \
# 655              TRANZACT       Fort Lee, NJ     Fort Lee, NJ
# 656                  JKGT  San Francisco, CA               -1
# 657            AccessHope      Irwindale, CA               -1
# 658  ChaTeck Incorporated  San Francisco, CA  Santa Clara, CA
# ...

# %%
da.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'min_salary', 'max_salary',
#        'avg_salary', 'job_state', 'same_state', 'company_age', 'python',
#        'excel', 'hadoop', 'spark', 'aws', 'tableau', 'big_data', 'job_simp',
#        'seniority'],
#       dtype='object')

# %%
da.shape
# Out:
# (660, 27)

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          660 non-null    object
#  1   Salary Estimate    660 non-null    int64
#  2   Job Description    660 non-null    object
#  3   Rating             660 non-null    float64
#  4   Company Name       660 non-null    object
#  5   Location           660 non-null    object
#  6   Headquarters       660 non-null    object
#  7   Size               660 non-null    object
#  8   Type of ownership  660 non-null    object
#  9   Industry           660 non-null    object
#  10  Sector             660 non-null    object
#  11  Revenue            660 non-null    object
#  12  min_salary         660 non-null    int64
#  13  max_salary         660 non-null    int64
#  14  avg_salary         660 non-null    int64
#  15  job_state          660 non-null    object
# ...

# %%
da.isnull().sum()
# Out:
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# min_salary           0
# max_salary           0
# avg_salary           0
# job_state            0
# same_state           0
# company_age          0
# python               0
# excel                0
# hadoop               0
# spark                0
# aws                  0
# tableau              0
# big_data             0
# job_simp             0
# seniority            0
# dtype: int64

# %%
da.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'min_salary', 'max_salary',
#        'avg_salary', 'job_state', 'same_state', 'company_age', 'python',
#        'excel', 'hadoop', 'spark', 'aws', 'tableau', 'big_data', 'job_simp',
#        'seniority'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
da['Company Name']=le.fit_transform(da['Company Name'])
da['Location']=le.fit_transform(da['Location'])
da['Industry']=le.fit_transform(da['Industry'])
da['Sector']=le.fit_transform(da['Sector'])
da['seniority']=le.fit_transform(da['seniority'])
da
# Out:
#              Job Title  Salary Estimate  \
# 0    Sr Data Scientist              171
# 1       Data Scientist              171
# 2       Data Scientist              171
# 3       Data Scientist              171
# 4       Data Scientist              171
# ..                 ...              ...
# 655     Data Scientist              167
# 656     Data Scientist              167
# 657     Data Scientist              167
# 658     Data Scientist              167
# 659     Data Scientist              167
#
#                                        Job Description  Rating  Company Name  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1           173
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2           233
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8            31
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5           184
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9            18
# ...

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          660 non-null    object
#  1   Salary Estimate    660 non-null    int64
#  2   Job Description    660 non-null    object
#  3   Rating             660 non-null    float64
#  4   Company Name       660 non-null    int64
#  5   Location           660 non-null    int64
#  6   Headquarters       660 non-null    object
#  7   Size               660 non-null    object
#  8   Type of ownership  660 non-null    object
#  9   Industry           660 non-null    int64
#  10  Sector             660 non-null    int64
#  11  Revenue            660 non-null    object
#  12  min_salary         660 non-null    int64
#  13  max_salary         660 non-null    int64
#  14  avg_salary         660 non-null    int64
#  15  job_state          660 non-null    object
# ...

# %%
x=da.drop(['Salary Estimate'],axis=1)
y=da['Salary Estimate']
x
# Out:
#              Job Title                                    Job Description  \
# 0    Sr Data Scientist  Description\n\nThe Senior Data Scientist is re...
# 1       Data Scientist  Secure our Nation, Ignite your Future\n\nJoin ...
# 2       Data Scientist  Overview\n\n\nAnalysis Group is one of the lar...
# 3       Data Scientist  JOB DESCRIPTION:\n\nDo you have a passion for ...
# 4       Data Scientist  Data Scientist\nAffinity Solutions / Marketing...
# ..                 ...                                                ...
# 655     Data Scientist  Summary\n\nWe’re looking for a data scientist ...
# 656     Data Scientist  Job Description\nBecome a thought leader withi...
# 657     Data Scientist  Join a thriving company that is changing the w...
# 658     Data Scientist  100 Remote Opportunity As an AINLP Data Scient...
# 659     Data Scientist  Description\n\nThe Data Scientist will be part...
#
#      Rating  Company Name  Location            Headquarters  \
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsRegressor
#from sklearn.tree import DecisionTreeClassifier

# %%
y
# Out:
# 0      171
# 1      171
# 2      171
# 3      171
# 4      171
#       ...
# 655    167
# 656    167
# 657    167
# 658    167
# 659    167
# Name: Salary Estimate, Length: 660, dtype: int64

# %%
feature_cols = ['Rating', 'company_age', 'same_state', 'python', 'excel', 'aws', 'spark']
x = da[feature_cols]

# %%
x
# Out:
#      Rating  company_age  same_state  python  excel  aws  spark
# 0       3.1           27           1       0      0    1      0
# 1       4.2           52           0       0      0    0      0
# 2       3.8           39           1       1      1    1      0
# 3       3.5           20           0       1      1    1      0
# 4       2.9           22           1       1      1    0      0
# ..      ...          ...         ...     ...    ...  ...    ...
# 655     3.6           31           1       1      1    0      0
# 656     0.0           -1           0       0      0    0      0
# 657     0.0           -1           0       1      1    0      0
# 658     5.0           -1           0       1      0    0      1
# 659     2.7           44           0       1      1    0      0
#
# [660 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[-0.41214819, -0.06886897,  1.20562498, ..., -0.8880416 ,
#          1.68440176, -0.62642243],
#        [ 0.51797175,  0.56033255, -0.82944532, ..., -0.8880416 ,
#         -0.59368259, -0.62642243],
#        [ 0.17974632,  0.23314776,  1.20562498, ...,  1.12607337,
#          1.68440176, -0.62642243],
#        ...,
#        [-3.03339529, -0.77357466, -0.82944532, ...,  1.12607337,
#         -0.59368259, -0.62642243],
#        [ 1.19442262, -0.77357466, -0.82944532, ..., -0.8880416 ,
#         -0.59368259,  1.59636684],
#        [-0.75037362,  0.35898807, -0.82944532, ...,  1.12607337,
#         -0.59368259, -0.62642243]], shape=(660, 7))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=47)
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print(y_pred)
# Out:
# [153.99341001 154.89140096 151.31419458 145.53327186 165.69989867
#  151.56174568 151.24576772 157.31376138 154.2486815  144.01654789
#  153.79584981 145.37922899 143.71886099 161.63242733 151.98149389
#  137.06246014 148.98465717 152.28781941 153.65701608 151.0041838
#  150.98897466 155.58513136 152.36566007 151.91119692 146.86820015
#  147.06400014 153.55624589 150.52417461 150.6369751  151.36543231
#  137.39687408 152.9647523  137.20867272 156.37236999 147.11721787
#  157.77058357 151.46024232 145.03408655 147.56372826 154.99386942
#  146.8585547  147.10780407 158.16406552 152.51215925 151.45110326
#  152.72865135 149.70156834 158.90012137 150.91787635 150.84950443
#  150.84950443 151.39981059 149.13864509 144.94944372 146.15874723
#  143.90472058 164.61640208 144.06886869 146.029504   151.97973368
#  151.0041838  154.43851432 147.94644527 161.62127063 154.58297855
#  143.69933009 145.20520866 151.80094612 155.46530193 136.23328768
# ...

# %%
from sklearn.metrics import r2_score
r2s=r2_score(y_test,y_pred)
print(r2s)

from sklearn.metrics import mean_absolute_error
m=mean_absolute_error(y_test,y_pred)
print(m)
# Out:
# -0.013164768274510408
# 36.820956221069046
